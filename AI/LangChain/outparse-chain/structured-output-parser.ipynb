// %%
import { StructuredOutputParser } from "@langchain/core/output_parsers";

const parser = StructuredOutputParser.fromNamesAndDescriptions({
  answer: "用户问题的答案",
  evidence: "你回答用户问题所依据的答案",
  confidence: "问题答案的可信度评分，格式是百分数",
});

parser.getFormatInstructions()

// %%
import { Ollama } from "@langchain/community/llms/ollama";
const ollama = new Ollama({
  baseUrl: "http://localhost:11434", 
  model: "qwen3-vl:4b", 
});
const prompt = PromptTemplate.fromTemplate("尽可能的回答用的问题 \n{instructions} \n{question}")
const chain = prompt.pipe(ollama).pipe(parser)

const res = await chain.invoke({
    question: "蒙娜丽莎的作者是谁？是什么时候绘制的",
    instructions: parser.getFormatInstructions()
})
                               
console.log(res)
// Out:
// {
//   answer: "蒙娜丽莎的作者是列奥纳多·达·芬奇（Leonardo da Vinci），创作时间约为1503年至1519年。",
//   evidence: "根据卢浮宫博物馆的官方记录及艺术史学界权威研究，蒙娜丽莎是达芬奇于1503-1519年间创作的肖像画，其创作过程与达芬奇的绘画技法特征（如晕涂法）高度吻合。",
//   confidence: "98%"
// }
