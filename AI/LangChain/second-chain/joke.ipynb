// %%
import { Ollama } from "@langchain/community/llms/ollama";

const ollama = new Ollama({
  baseUrl: "http://localhost:11434", 
  model: "qwen3-vl:4b", 
});


const res = await ollama.invoke("你给老子讲个笑话");
res;
// Out:
// "哈哈，来一个程序员专属冷笑话 🤪：\n" +
//   "\n" +
//   "**“为什么程序员总是分不清万圣节和圣诞节？”**  \n" +
//   "**“因为 Oct 31 == Dec 25！”**  \n" +
//   "\n" +
//   "（解释：在程序员眼里，`Oct` 是八进制数，`31` 在八进制里等于十进制的 25，所以 `Oct 31` 就是 `Dec 25` —— 万圣节和圣诞节被“等价”了 😂）\n" +
//   "\n" +
//   "当然，如果你觉得太硬核，我再补个通俗版：  \n" +
//   "**“我养了只鹦鹉，它总说‘你好’，但后来它学会了说‘你有病’。”**  \n" +
//   "**—— 因为它只会说 ‘Hello’（你好）和 ‘Yo’（你有病）……**  \n" +
//   "（*其实这是个谐音梗，但可能有人听不懂…* 😅）\n" +
//   "\n" +
//   "选哪个？你先笑我一下吧！😉"
