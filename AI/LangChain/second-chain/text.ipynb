// %%
import { Ollama } from "@langchain/community/llms/ollama";

const ollama = new Ollama({
  baseUrl: "http://localhost:11434", 
  model: "qwen3-vl:4b", 
});


const res = await ollama.invoke("讲个笑话");
res;
// Out:
// "哈哈，讲个轻松的笑话给你：\n" +
//   "\n" +
//   "**“为什么数学老师总是不开心？因为她的丈夫是负数！”**\n" +
//   "\n" +
//   "（笑点：数学中的“负数”在中文里谐音“负数”，但“负”字又暗示“不开心”，所以听起来很搞笑～）\n" +
//   "\n" +
//   "怎么样？是不是觉得有点意思？😄 如果你再想听，我还可以编个关于AI的冷笑话哦！（不过我得先确认你有没有被笑到……）"
