// %%
import ignore from "npm:/ignore";
import { GithubRepoLoader } from "langchain/document_loaders/web/github";

const loader = new GithubRepoLoader('https://github.com/shenyWill/day-day-start', {
    branch: "master",
    recursive: false, 
    unknown: "warn", 
    ignorePaths: ["*.md", "yarn.lock", "*.json"],
    accessToken: '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'
});

const docs = await loader.load();

docs;
// Out:
// [
//   Document {
//     pageContent: "\x00\x00\x00\x01Bud1\x00\x00\x10\x00\x00\x00\b\x00\x00\x00\x10\x00\x00\x00\x04\n" +
// ...
